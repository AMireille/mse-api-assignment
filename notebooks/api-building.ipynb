# %%
#import needed libraries 
from fastapi import FastAPI, Query, Path,HTTPException
from typing import Optional
from datetime import date
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import os

# %%
#load environment variables
load_dotenv()

PGHOST = os.getenv("PGHOST")
PGPORT = os.getenv("PGPORT", "5432")
PGDATABASE = os.getenv("PGDATABASE")
PGUSER = os.getenv("PGUSER")
PGPASSWORD = os.getenv("PGPASSWORD")

# %%
# Create SQLAlchemy engine 
connection_string = f"postgresql+psycopg2://{PGUSER}:{PGPASSWORD}@{PGHOST}:{PGPORT}/{PGDATABASE}"
print("Connection psql string:", connection_string)

engine = create_engine(connection_string, pool_pre_ping=True)
# Out:
# Connection psql string: postgresql+psycopg2://kir2351763:password@localhost:5432/mse_db

# %%
company_sector_mapping = {
    'AIRTEL': 'Telecommunication',
    'BHL': 'Hospitality',
    'FDHB': 'Finance',
    'FMBCH': 'Finance',
    'ICON': 'Construction',
    'ILLOVO': 'Agriculture',
    'MPICO': 'Construction',
    'NBM': 'Finance',
    'NBS': 'Finance',
    'NICO': 'Finance',
    'NITL': 'Finance',
    'OMU': 'Finance',
    'PCL': 'Investments',
    'STANDARD': 'Finance',
    'SUNBIRD': 'Hospitality',
    'TNM': 'Telecommunication'
}

# %%
# Initialize FastAPI app
app = FastAPI()

# %%
# Home end-point
@app.get("/")
def home():
    return {"message": "Welcome to the MSE API!"}

# %%
#First end-point: Call with Query parameters
@app.get("/companies")
def get_companies(sector: Optional[str] = Query(None, description="Filter companies by sector")):
    """Get list of companies with optional sector filtering."""
    df=pd.read_sql("SELECT * FROM tickers", con=engine)
    df['Sector'] = df['ticker'].map(company_sector_mapping)
    df=df[['ticker','name','Sector','date_listed']]
    if sector:
        df=df[df['Sector']==sector]
    data=df.to_dict(orient='records')
    return {'count':len(data), 'data':data}

# %%
#Second end-point: Call with Path parameters
@app.get("/companies/{ticker}")
def get_company_details(ticker:str):
    """Get company details and total records for a given ticker symbol."""
    #counter details
    df=pd.read_sql("SELECT * FROM tickers t JOIN daily_prices p ON t.counter_id=p.counter_id", con=engine)
    df['Sector'] = df['ticker'].map(company_sector_mapping)
    df=[df['ticker']==ticker]
    df=df[['ticker','name','Sector','date_listed']]
    company_details=df.to_dict(orient='records')
    records=len(df)
    return {'Company details':company_details,'Total records':records}

# %%
def get_company_details(ticker:str):
    """Get company details and total records for a given ticker symbol."""
    #ticker details
    query = text("""
    SELECT t.ticker, t.name, t.date_listed, p.counter_id
    FROM tickers t
    JOIN daily_prices p ON t.counter_id = p.counter_id
    WHERE t.ticker = :ticker
    """)
    df = pd.read_sql(query, con=engine, params={"ticker": ticker})
    if df.empty:
        raise HTTPException(status_code=404, detail=f"No company found for ticker '{ticker}'.")
    df['Sector'] = df['ticker'].map(company_sector_mapping)
    df = df[df['ticker'] == ticker]
    df=df[['ticker','name','Sector','date_listed']]
    company_details = df[['ticker', 'name', 'Sector', 'date_listed']].drop_duplicates().to_dict(orient='records')
    total_records = len(df)
    return {'Company details':company_details,'Total records':total_records}

# %%
get_company_details("AIRTEL")
# Out:
# {'Company details': [{'ticker': 'AIRTEL',
#    'name': 'AIRTEL MALAWI PLC',
#    'Sector': 'Telecommunication',
#    'date_listed': datetime.date(2020, 2, 24)}],
#  'Total records': 1209}

# %%
#Third end-point
@app.get("/prices/daily")
def get_daily_prices(
    ticker: str = Query(..., description="Stock ticker symbol"),
    start_date: Optional[date] = Query(None, description="Start date (YYYY-MM-DD)"),
    end_date: Optional[date] = Query(None, description="End date (YYYY-MM-DD)"),
    limit: Optional[int] = Query(100, description="Maximum records to return")
    ): 
    """ Get daily price data for a given ticker symbol within an optional date range and limit."""
    #fetch counter name from counter table
    df=pd.read_sql("SELECT * FROM tickers t JOIN daily_prices p ON t.counter_id=p.counter_id", con=engine)
    df=df[df['ticker']==ticker]
    df.rename(columns={['open_mwk','high_mwk','low_mwk','close_mwk','volume','trade_date']:['open',' high','low','close','volume','trade_date']}, inplace=True)

    # Filter by date range
    if start_date:
        df = df[df['trade_date'] >= start_date]
    if end_date:
        df = df[df['trade_date'] <= end_date]

    # Apply limit (max 1000)
    limit = min(limit or 100, 1000)
    df = df.head(limit)
    df = df.fillna('') 
    return {"Company": ticker, "data":df.to_dict(orient='records')}

# %%
def get_daily_prices_by_date_range(
    ticker: str = Query(..., description="Stock ticker symbol"),
    start_date: Optional[date] = None,
    end_date: Optional[date] = None,
    limit: Optional[int] = 100):
    """ Get daily price data for a given ticker symbol within an optional date range and limit."""
    #fetch counter name from counter table
    query = text("""
    SELECT  p.trade_date, p.open_mwk, p.high_mwk, p.low_mwk, p.close_mwk, p.volume
    FROM tickers t
    JOIN daily_prices p ON t.counter_id = p.counter_id
    WHERE t.ticker = :ticker
    """)
    df = pd.read_sql(query, con=engine, params={'ticker': ticker})
    df.rename(columns={
    'open_mwk': 'open',
    'high_mwk': 'high',
    'low_mwk': 'low',
    'close_mwk': 'close',
    'volume': 'volume',
    'trade_date': 'trade_date'
    }, inplace=True)
    print(df)
    df['trade_date'] = pd.to_datetime(df['trade_date'])
    # Filter by date range
    
    if start_date:
        df = df[df['trade_date'] >=start_date]
    if end_date:
        df = df[df['trade_date'] <=end_date]

    # Apply limit (max 1000)
    limit = min(limit or 100, 1000)
    df = df.head(limit)
    df = df.fillna('') 
    return {"Company": ticker, "data":df.to_dict(orient='records')}
get_daily_prices_by_date_range("NICO")
# Out:
#       trade_date  open     high      low    close    volume
# 0     2025-09-19   2.0  1739.93  1739.91  1739.92  102670.0
# 1     2025-09-18   2.0  1739.98  1739.92  1739.94   94047.0
# 2     2025-09-17   2.0  1739.98  1739.78  1739.96   32696.0
# 3     2025-09-15   2.0  1740.00  1739.97  1739.99   28044.0
# 4     2025-09-12   2.0  1740.01  1739.99  1740.00  165086.0
# ...          ...   ...      ...      ...      ...       ...
# 1771  2017-07-10   2.0  1350.00  1350.00  1350.00  150000.0
# 1772  2017-07-07   2.0      NaN      NaN      NaN       NaN
# 1773  2017-07-04   2.0      NaN      NaN      NaN       NaN
# 1774  2017-06-30   2.0      NaN      NaN      NaN       NaN
# 1775  2017-06-29   2.0      NaN      NaN      NaN       NaN
#
# [1776 rows x 6 columns]
# ggoing for date range
# start date None
# {'Company': 'NICO',
#  'data': [{'trade_date': Timestamp('2025-09-19 00:00:00'),
#    'open': 2.0,
#    'high': 1739.93,
#    'low': 1739.91,
#    'close': 1739.92,
#    'volume': 102670.0},
#   {'trade_date': Timestamp('2025-09-18 00:00:00'),
#    'open': 2.0,
#    'high': 1739.98,
#    'low': 1739.92,
#    'close': 1739.94,
#    'volume': 94047.0},
#   {'trade_date': Timestamp('2025-09-17 00:00:00'),
#    'open': 2.0,
#    'high': 1739.98,
#    'low': 1739.78,
#    'close': 1739.96,
#    'volume': 32696.0},
#   {'trade_date': Timestamp('2025-09-15 00:00:00'),
#    'open': 2.0,
#    'high': 1740.0,
#    'low': 1739.97,
#    'close': 1739.99,
#    'volume': 28044.0},
#   {'trade_date': Timestamp('2025-09-12 00:00:00'),
#    'open': 2.0,
#    'high': 1740.01,
#    'low': 1739.99,
#    'close': 1740.0,
#    'volume': 165086.0},
#   {'trade_date': Timestamp('2025-09-11 00:00:00'),
#    'open': 2.0,
#    'high': 1740.01,
#    'low': 1740.0,
#    'close': 1740.01,
#    'volume': 78775.0},
#   {'trade_date': Timestamp('2025-09-10 00:00:00'),
#    'open': 2.0,
#    'high': 1740.02,
#    'low': 1740.0,
#    'close': 1740.01,
#    'volume': 80031.0},
#   {'trade_date': Timestamp('2025-09-09 00:00:00'),
#    'open': 2.0,
#    'high': 1740.01,
#    'low': 1739.99,
#    'close': 1740.0,
#    'volume': 108721.0},
#   {'trade_date': Timestamp('2025-09-08 00:00:00'),
#    'open': 2.0,
#    'high': 1740.0,
#    'low': 1739.98,
#    'close': 1739.99,
#    'volume': 8290.0},
#   {'trade_date': Timestamp('2025-09-05 00:00:00'),
#    'open': 2.0,
#    'high': 1740.0,
#    'low': 1739.99,
#    'close': 1740.0,
#    'volume': 106674.0},
#   {'trade_date': Timestamp('2025-09-04 00:00:00'),
#    'open': 2.0,
#    'high': 1740.01,
#    'low': 1739.99,
#    'close': 1740.01,
#    'volume': 53110.0},
#   {'trade_date': Timestamp('2025-09-03 00:00:00'),
#    'open': 2.0,
#    'high': 1740.02,
#    'low': 1740.0,
#    'close': 1740.01,
#    'volume': 83432.0},
#   {'trade_date': Timestamp('2025-09-02 00:00:00'),
#    'open': 2.0,
#    'high': 1740.01,
#    'low': 1740.01,
#    'close': 1740.01,
#    'volume': 10000.0},
#   {'trade_date': Timestamp('2025-09-01 00:00:00'),
#    'open': 2.0,
#    'high': 1740.02,
#    'low': 1740.01,
#    'close': 1740.01,
#    'volume': 29891.0},
#   {'trade_date': Timestamp('2025-08-29 00:00:00'),
#    'open': 2.0,
#    'high': 1740.01,
#    'low': 1740.0,
#    'close': 1740.01,
#    'volume': 170602.0},
#   {'trade_date': Timestamp('2025-08-28 00:00:00'),
#    'open': 2.0,
#    'high': 1514.18,
#    'low': 1514.18,
#    'close': 1514.18,
#    'volume': 80839.0},
#   {'trade_date': Timestamp('2025-08-27 00:00:00'),
#    'open': 2.0,
#    'high': 1514.01,
#    'low': 1514.0,
#    'close': 1514.01,
#    'volume': 13146.0},
#   {'trade_date': Timestamp('2025-08-26 00:00:00'),
#    'open': 2.0,
#    'high': 1317.04,
#    'low': 1317.04,
#    'close': 1317.04,
#    'volume': 889.0},
#   {'trade_date': Timestamp('2025-08-25 00:00:00'),
#    'open': 2.0,
#    'high': '',
#    'low': '',
#    'close': 1317.01,
#    'volume': 0.0},
#   {'trade_date': Timestamp('2025-08-22 00:00:00'),
#    'open': 2.0,
#    'high': 1317.02,
#    'low': 1317.01,
#    'close': 1317.01,
#    'volume': 53500.0},
#   {'trade_date': Timestamp('2025-08-21 00:00:00'),
#    'open': 2.0,
#    'high': 1316.05,
#    'low': 1300.01,
#    'close': 1304.67,
#    'volume': 75261.0},
#   {'trade_date': Timestamp('2025-08-20 00:00:00'),
#    'open': 2.0,
#    'high': 1300.0,
#    'low': 1144.4,
#    'close': 1159.41,
#    'volume': 52000.0},
#   {'trade_date': Timestamp('2025-08-19 00:00:00'),
#    'open': 2.0,
#    'high': 1144.4,
#    'low': 1144.38,
#    'close': 1144.38,
#    'volume': 78741.0},
#   {'trade_date': Timestamp('2025-08-18 00:00:00'),
#    'open': 2.0,
#    'high': 1144.37,
#    'low': 1144.37,
#    'close': 1144.37,
#    'volume': 120.0},
#   {'trade_date': Timestamp('2025-08-15 00:00:00'),
#    'open': 2.0,
#    'high': 1144.37,
#    'low': 1144.33,
#    'close': 1144.34,
#    'volume': 140231.0},
#   {'trade_date': Timestamp('2025-08-14 00:00:00'),
#    'open': 2.0,
#    'high': 1144.33,
#    'low': 1144.33,
#    'close': 1144.33,
#    'volume': 348979.0},
#   {'trade_date': Timestamp('2025-08-13 00:00:00'),
#    'open': 2.0,
#    'high': 1144.29,
#    'low': 1144.28,
#    'close': 1144.29,
#    'volume': 10000.0},
#   {'trade_date': Timestamp('2025-08-12 00:00:00'),
#    'open': 2.0,
#    'high': 1144.28,
#    'low': 995.15,
#    'close': 1142.41,
#    'volume': 12474.0},
#   {'trade_date': Timestamp('2025-08-11 00:00:00'),
#    'open': 2.0,
#    'high': '',
#    'low': '',
#    'close': 995.13,
#    'volume': 0.0},
#   {'trade_date': Timestamp('2025-08-08 00:00:00'),
#    'open': 2.0,
#    'high': 995.14,
#    'low': 995.13,
#    'close': 995.13,
#    'volume': 51000.0},
#   {'trade_date': Timestamp('2025-08-07 00:00:00'),
#    'open': 2.0,
#    'high': 995.12,
#    'low': 995.12,
#    'close': 995.12,
#    'volume': 10000.0},
#   {'trade_date': Timestamp('2025-08-06 00:00:00'),
#    'open': 2.0,
#    'high': 995.09,
#    'low': 995.09,
#    'close': 995.09,
#    'volume': 12000.0},
#   {'trade_date': Timestamp('2025-08-05 00:00:00'),
#    'open': 2.0,
#    'high': 995.04,
#    'low': 995.03,
#    'close': 995.03,
#    'volume': 8805.0},
#   {'trade_date': Timestamp('2025-08-04 00:00:00'),
#    'open': 2.0,
#    'high': 995.01,
#    'low': 995.01,
#    'close': 995.01,
#    'volume': 13852.0},
#   {'trade_date': Timestamp('2025-08-01 00:00:00'),
#    'open': 2.0,
#    'high': 995.02,
#    'low': 995.01,
#    'close': 995.01,
#    'volume': 27055.0},
#   {'trade_date': Timestamp('2025-07-31 00:00:00'),
#    'open': 2.0,
#    'high': 995.01,
#    'low': 995.0,
#    'close': 995.0,
#    'volume': 26618.0},
#   {'trade_date': Timestamp('2025-07-30 00:00:00'),
#    'open': 2.0,
#    'high': 995.01,
#    'low': 994.9,
#    'close': 994.99,
#    'volume': 126626.0},
#   {'trade_date': Timestamp('2025-07-29 00:00:00'),
#    'open': 2.0,
#    'high': 994.89,
#    'low': 994.85,
#    'close': 994.89,
#    'volume': 120197.0},
#   {'trade_date': Timestamp('2025-07-28 00:00:00'),
#    'open': 2.0,
#    'high': 994.86,
#    'low': 994.85,
#    'close': 994.86,
#    'volume': 1253.0},
#   {'trade_date': Timestamp('2025-07-25 00:00:00'),
#    'open': 2.0,
#    'high': 994.83,
#    'low': 994.82,
#    'close': 994.83,
#    'volume': 3290.0},
#   {'trade_date': Timestamp('2025-07-24 00:00:00'),
#    'open': 2.0,
#    'high': 994.8,
#    'low': 994.77,
#    'close': 994.78,
#    'volume': 13233.0},
#   {'trade_date': Timestamp('2025-07-23 00:00:00'),
#    'open': 2.0,
#    'high': '',
#    'low': '',
#    'close': 994.77,
#    'volume': 0.0},
#   {'trade_date': Timestamp('2025-07-22 00:00:00'),
#    'open': 2.0,
#    'high': 994.77,
#    'low': 994.77,
#    'close': 994.77,
#    'volume': 60000.0},
#   {'trade_date': Timestamp('2025-07-21 00:00:00'),
#    'open': 2.0,
#    'high': 994.76,
#    'low': 994.76,
#    'close': 994.76,
#    'volume': 1500.0},
#   {'trade_date': Timestamp('2025-07-18 00:00:00'),
#    'open': 2.0,
#    'high': 994.75,
#    'low': 994.75,
#    'close': 994.75,
#    'volume': 31018.0},
#   {'trade_date': Timestamp('2025-07-17 00:00:00'),
#    'open': 2.0,
#    'high': 994.75,
#    'low': 994.74,
#    'close': 994.75,
#    'volume': 61907.0},
#   {'trade_date': Timestamp('2025-07-16 00:00:00'),
#    'open': 2.0,
#    'high': 994.75,
#    'low': 865.02,
#    'close': 869.77,
#    'volume': 4041.0},
#   {'trade_date': Timestamp('2025-07-15 00:00:00'),
#    'open': 2.0,
#    'high': 865.02,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 123773.0},
#   {'trade_date': Timestamp('2025-07-14 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 104396.0},
#   {'trade_date': Timestamp('2025-07-11 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 864.99,
#    'close': 865.0,
#    'volume': 516016.0},
#   {'trade_date': Timestamp('2025-07-10 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 108628.0},
#   {'trade_date': Timestamp('2025-07-09 00:00:00'),
#    'open': 2.0,
#    'high': 865.01,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 233662.0},
#   {'trade_date': Timestamp('2025-07-08 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 149685.0},
#   {'trade_date': Timestamp('2025-07-04 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 864.99,
#    'close': 865.0,
#    'volume': 122510.0},
#   {'trade_date': Timestamp('2025-07-03 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 869720.0},
#   {'trade_date': Timestamp('2025-07-02 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 39236.0},
#   {'trade_date': Timestamp('2025-07-01 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 864.99,
#    'close': 865.0,
#    'volume': 79153.0},
#   {'trade_date': Timestamp('2025-06-30 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 217372.0},
#   {'trade_date': Timestamp('2025-06-27 00:00:00'),
#    'open': 2.0,
#    'high': 865.0,
#    'low': 865.0,
#    'close': 865.0,
#    'volume': 948091.0},
#   {'trade_date': Timestamp('2025-06-26 00:00:00'),
#    'open': 2.0,
#    'high': 865.01,
#    'low': 854.01,
#    'close': 859.23,
#    'volume': 1774798.0},
#   {'trade_date': Timestamp('2025-06-25 00:00:00'),
#    'open': 2.0,
#    'high': 854.01,
#    'low': 854.0,
#    'close': 854.01,
#    'volume': 546811.0},
#   {'trade_date': Timestamp('2025-06-24 00:00:00'),
#    'open': 2.0,
#    'high': 854.01,
#    'low': 854.01,
#    'close': 854.01,
#    'volume': 117941.0},
#   {'trade_date': Timestamp('2025-06-23 00:00:00'),
#    'open': 2.0,
#    'high': 854.01,
#    'low': 854.0,
#    'close': 854.0,
#    'volume': 551809.0},
#   {'trade_date': Timestamp('2025-06-20 00:00:00'),
#    'open': 2.0,
#    'high': 854.01,
#    'low': 776.4,
#    'close': 844.22,
#    'volume': 234734.0},
#   {'trade_date': Timestamp('2025-06-19 00:00:00'),
#    'open': 2.0,
#    'high': 776.37,
#    'low': 776.37,
#    'close': 776.37,
#    'volume': 7253326.0},
#   {'trade_date': Timestamp('2025-06-18 00:00:00'),
#    'open': 2.0,
#    'high': 776.37,
#    'low': 776.37,
#    'close': 776.37,
#    'volume': 35396.0},
#   {'trade_date': Timestamp('2025-06-17 00:00:00'),
#    'open': 2.0,
#    'high': 776.37,
#    'low': 776.36,
#    'close': 776.36,
#    'volume': 455134.0},
#   {'trade_date': Timestamp('2025-06-16 00:00:00'),
#    'open': 2.0,
#    'high': 776.37,
#    'low': 776.37,
#    'close': 776.37,
#    'volume': 1866.0},
#   {'trade_date': Timestamp('2025-06-13 00:00:00'),
#    'open': 2.0,
#    'high': 776.36,
#    'low': 725.01,
#    'close': 748.66,
#    'volume': 30804.0},
#   {'trade_date': Timestamp('2025-06-12 00:00:00'),
#    'open': 2.0,
#    'high': 776.37,
#    'low': 725.0,
#    'close': 725.64,
#    'volume': 771689.0},
#   {'trade_date': Timestamp('2025-06-11 00:00:00'),
#    'open': 2.0,
#    'high': 776.38,
#    'low': 700.0,
#    'close': 716.77,
#    'volume': 122621.0},
#   {'trade_date': Timestamp('2025-06-10 00:00:00'),
#    'open': 2.0,
#    'high': 776.38,
#    'low': 776.37,
#    'close': 776.37,
#    'volume': 67957.0},
#   {'trade_date': Timestamp('2025-06-06 00:00:00'),
#    'open': 2.0,
#    'high': 776.39,
#    'low': 776.38,
#    'close': 776.38,
#    'volume': 45566.0},
#   {'trade_date': Timestamp('2025-06-05 00:00:00'),
#    'open': 2.0,
#    'high': 776.39,
#    'low': 776.39,
#    'close': 776.39,
#    'volume': 8077.0},
#   {'trade_date': Timestamp('2025-06-04 00:00:00'),
#    'open': 2.0,
#    'high': 776.39,
#    'low': 776.39,
#    'close': 776.39,
#    'volume': 475.0},
#   {'trade_date': Timestamp('2025-06-03 00:00:00'),
#    'open': 2.0,
#    'high': 776.39,
#    'low': 776.38,
#    'close': 776.39,
#    'volume': 10116.0},
#   {'trade_date': Timestamp('2025-06-02 00:00:00'),
#    'open': 2.0,
#    'high': 776.4,
#    'low': 776.39,
#    'close': 776.4,
#    'volume': 13793.0},
#   {'trade_date': Timestamp('2025-05-30 00:00:00'),
#    'open': 2.0,
#    'high': 776.41,
#    'low': 776.4,
#    'close': 776.41,
#    'volume': 177912.0},
#   {'trade_date': Timestamp('2025-05-29 00:00:00'),
#    'open': 2.0,
#    'high': 776.42,
#    'low': 776.35,
#    'close': 776.4,
#    'volume': 950814.0},
#   {'trade_date': Timestamp('2025-05-28 00:00:00'),
#    'open': 2.0,
#    'high': 776.35,
#    'low': 776.34,
#    'close': 776.35,
#    'volume': 391466.0},
#   {'trade_date': Timestamp('2025-05-27 00:00:00'),
#    'open': 2.0,
#    'high': 776.39,
#    'low': 776.36,
#    'close': 776.37,
#    'volume': 79506.0},
#   {'trade_date': Timestamp('2025-05-26 00:00:00'),
#    'open': 2.0,
#    'high': 776.42,
#    'low': 776.39,
#    'close': 776.4,
#    'volume': 122586.0},
#   {'trade_date': Timestamp('2025-05-23 00:00:00'),
#    'open': 2.0,
#    'high': 776.45,
#    'low': 776.43,
#    'close': 776.43,
#    'volume': 26238.0},
#   {'trade_date': Timestamp('2025-05-22 00:00:00'),
#    'open': 2.0,
#    'high': 776.49,
#    'low': 776.46,
#    'close': 776.47,
#    'volume': 21812.0},
#   {'trade_date': Timestamp('2025-05-21 00:00:00'),
#    'open': 2.0,
#    'high': 776.53,
#    'low': 776.5,
#    'close': 776.52,
#    'volume': 45832.0},
#   {'trade_date': Timestamp('2025-05-20 00:00:00'),
#    'open': 2.0,
#    'high': 776.56,
#    'low': 776.53,
#    'close': 776.53,
#    'volume': 11706.0},
#   {'trade_date': Timestamp('2025-05-19 00:00:00'),
#    'open': 2.0,
#    'high': 776.57,
#    'low': 776.56,
#    'close': 776.56,
#    'volume': 36679.0},
#   {'trade_date': Timestamp('2025-05-16 00:00:00'),
#    'open': 2.0,
#    'high': 776.57,
#    'low': 776.57,
#    'close': 776.57,
#    'volume': 37796.0},
#   {'trade_date': Timestamp('2025-05-15 00:00:00'),
#    'open': 2.0,
#    'high': 776.6,
#    'low': 776.57,
#    'close': 776.58,
#    'volume': 24658.0},
#   {'trade_date': Timestamp('2025-05-13 00:00:00'),
#    'open': 2.0,
#    'high': 776.65,
#    'low': 776.59,
#    'close': 776.6,
#    'volume': 242413.0},
#   {'trade_date': Timestamp('2025-05-12 00:00:00'),
#    'open': 2.0,
#    'high': 776.65,
#    'low': 776.65,
#    'close': 776.65,
#    'volume': 10249.0},
#   {'trade_date': Timestamp('2025-05-09 00:00:00'),
#    'open': 2.0,
#    'high': 776.66,
#    'low': 776.64,
#    'close': 776.65,
#    'volume': 155464.0},
#   {'trade_date': Timestamp('2025-05-08 00:00:00'),
#    'open': 2.0,
#    'high': 776.66,
#    'low': 776.64,
#    'close': 776.66,
#    'volume': 29877.0},
#   {'trade_date': Timestamp('2025-05-07 00:00:00'),
#    'open': 2.0,
#    'high': 776.65,
#    'low': 776.64,
#    'close': 776.65,
#    'volume': 9384.0},
#   {'trade_date': Timestamp('2025-05-06 00:00:00'),
#    'open': 2.0,
#    'high': 776.65,
#    'low': 776.64,
#    'close': 776.65,
#    'volume': 63441.0},
#   {'trade_date': Timestamp('2025-05-05 00:00:00'),
#    'open': 2.0,
#    'high': 776.65,
#    'low': 776.64,
#    'close': 776.65,
#    'volume': 2926.0},
#   {'trade_date': Timestamp('2025-05-02 00:00:00'),
#    'open': 2.0,
#    'high': 776.67,
#    'low': 776.64,
#    'close': 776.66,
#    'volume': 21466.0},
#   {'trade_date': Timestamp('2025-04-30 00:00:00'),
#    'open': 2.0,
#    'high': 776.68,
#    'low': 776.67,
#    'close': 776.68,
#    'volume': 123901.0},
#   {'trade_date': Timestamp('2025-04-29 00:00:00'),
#    'open': 2.0,
#    'high': 776.69,
#    'low': 776.68,
#    'close': 776.69,
#    'volume': 35643.0},
#   {'trade_date': Timestamp('2025-04-28 00:00:00'),
#    'open': 2.0,
#    'high': 776.7,
#    'low': 776.69,
#    'close': 776.69,
#    'volume': 741582.0}]}

# %%
#Fourth end-point
@app.get("/prices/range")
def get_daily_prices(
    ticker: str = Query(..., description="Stock ticker symbol"),
    year: int = Query(..., description="Year"),
    month: Optional[int] = Query(None, description="Month of the year"),
    ):
    """ Get daily price data for a given ticker symbol within a specified year and optional month."""
    #fetch counter name from counter table
    df=pd.read_sql("SELECT p.trade_date,p.open_mwk,p.high_mwk,p.low_mwk,p.close_mwk,p.volume FROM tickers t JOIN daily_prices p ON t.counter_id=p.counter_id", con=engine)
    df.columns=['Period','open',' high','low','close','Total Volume']

    df['Period'] = pd.to_datetime(df['Period'])
    df = df[df['Period'].dt.year == year]
    if month:
        df = df[df['Period'].dt.month == month]

    df = df.fillna('') 
    return {"Company": ticker, "data":df.to_dict(orient='records')}

# %%
def get_daily_prices_by_period(
    ticker: str = Query(..., description="Stock ticker symbol"),
    year: int = Query(..., description="Year"),
    month: Optional[int] = Query(default=None, description="Month of the year"),
):
    """Get daily price data for a given ticker symbol within a specified year and optional month."""
    
    query = text("""
        SELECT p.trade_date, p.open_mwk, p.high_mwk, p.low_mwk, p.close_mwk, p.volume
        FROM tickers t
        JOIN daily_prices p ON t.counter_id = p.counter_id
        WHERE t.ticker = :ticker
    """)
    
    df = pd.read_sql(query, con=engine, params={"ticker": ticker})
    
    df.columns = ['Period', 'Open', 'High', 'Low', 'Close', 'TotalVolume']
    df['Period'] = pd.to_datetime(df['Period'])
    
    df = df[df['Period'].dt.year == year]
    print(df)
    print("month",month)
    print("*********************")
    if month:
        df = df[df['Period'].dt.month == month]
    print(df)
    df['Period'] = df['Period'].dt.strftime('%Y-%m-%d')
    df = df.fillna('')
    
    return {"Company": ticker, "data": df.to_dict(orient='records')}

get_daily_prices_by_period('NICO',2025)
# Out:
#         Period  Open     High      Low    Close  TotalVolume
# 0   2025-09-19   2.0  1739.93  1739.91  1739.92     102670.0
# 1   2025-09-18   2.0  1739.98  1739.92  1739.94      94047.0
# 2   2025-09-17   2.0  1739.98  1739.78  1739.96      32696.0
# 3   2025-09-15   2.0  1740.00  1739.97  1739.99      28044.0
# 4   2025-09-12   2.0  1740.01  1739.99  1740.00     165086.0
# ..         ...   ...      ...      ...      ...          ...
# 171 2025-01-08   2.0   419.00   419.00   419.00      11933.0
# 172 2025-01-07   2.0   419.02   419.00   419.00      12885.0
# 173 2025-01-06   2.0   419.02   419.01   419.01       7503.0
# 174 2025-01-03   2.0   419.02   419.02   419.02      86914.0
# 175 2025-01-02   2.0   419.02   419.01   419.02      20714.0
#
# [176 rows x 6 columns]
# month annotation=NoneType required=False default=None description='Month of the year' json_schema_extra={}
# *********************
# Empty DataFrame
# Columns: [Period, Open, High, Low, Close, TotalVolume]
# Index: []
# {'Company': 'NICO', 'data': []}

# %%
#Fifth end-point
@app.get("/prices/latest")
def get_recent_prices(
    ticker: Optional[str] = Query(None, description="Stock ticker symbol"),
    ):
    """ Get the most recent price data for a given ticker symbol, including latest price,
    previous price, and percentage change."""
     #fetch counter name from counter table
    df=pd.read_sql("SELECT  p.trade_date,p.open_mwk,p.high_mwk,p.low_mwk,p.close_mwk,p.volume FROM tickers t JOIN daily_prices p ON t.counter_id=p.counter_id", con=engine)
    df.columns=['trade_date','open',' high','low','close','Total Volume']

    df['trade_date'] = pd.to_datetime(df['trade_date'])
    df_sorted = df.sort_values(by='trade_date', ascending=False).reset_index(drop=True)

    # Latest price
    latest = df_sorted.iloc[0]
    latest_date = latest['trade_date']
    latest_price = latest['close']
    
    # Previous price
    if len(df_sorted) > 1:
        prev_price = df_sorted.iloc[1]['close']
        change = latest_price - prev_price
        change_percentage = (change / prev_price) * 100 if prev_price != 0 else 0
    else:
        prev_price = None
        change = None
        change_percentage = None
    return {
        "ticker": ticker,
        "latest_date": latest_date,
        "latest_price": latest_price,
        "previous_price": prev_price,
        "change": change,
        "change_percentage": str(round(change_percentage,3))+'%'
    }

# %%
import uvicorn
uvicorn.run("app", host="127.0.0.1", port=8000, reload=True)
# Out:
# INFO:     Will watch for changes in these directories: ['/home/kir2351763/RRA/other trainings/DSCBI/assignments/mse-api-assignment/notebooks']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [12585] using WatchFiles
# ERROR:    Error loading ASGI app. Import string "app" must be in format "<module>:<attribute>".
# INFO:     Stopping reloader process [12585]
